# %%
from ultralytics import YOLO

# %%
# Load a model
model = YOLO('yolov8s.pt')  # load a pretrained model (recommended for training)

# Train the model
results = model.train(data='./VisDrone.yaml', epochs=100, imgsz=640)
# Out:
# Ultralytics YOLOv8.0.26  Python-3.11.0 torch-2.0.1+cpu CPU
# yolo\engine\trainer: task=detect, mode=train, model=yolov8s.yaml, data=./VisDrone.yaml, epochs=100, patience=50, batch=16, imgsz=640, save=True, cache=False, device=, workers=8, project=None, name=None, exist_ok=False, pretrained=False, optimizer=SGD, verbose=True, seed=0, deterministic=True, single_cls=False, image_weights=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, overlap_mask=True, mask_ratio=4, dropout=False, val=True, save_json=False, save_hybrid=False, conf=0.001, iou=0.7, max_det=300, half=False, dnn=False, plots=False, source=ultralytics/assets/, show=False, save_txt=False, save_conf=False, save_crop=False, hide_labels=False, hide_conf=False, vid_stride=1, line_thickness=3, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=17, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.001, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, fl_gamma=0.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, v5loader=False, save_dir=runs\detect\train4
#
# Dataset './VisDrone.yaml' not found , missing paths ['C:\\Users\\lekev\\OneDrive - University of Waterloo\\University\\FYDP\\CrowdQuote\\ComputerVision-Subsystem\\datasets\\VisDrone\\VisDrone2019-DET-val\\images']
# Downloading https://github.com/ultralytics/yolov5/releases/download/v1.0/VisDrone2019-DET-train.zip to C:\Users\lekev\OneDrive - University of Waterloo\University\FYDP\CrowdQuote\ComputerVision-Subsystem\datasets\VisDrone\VisDrone2019-DET-train.zip...
# Downloading https://github.com/ultralytics/yolov5/releases/download/v1.0/VisDrone2019-DET-val.zip to C:\Users\lekev\OneDrive - University of Waterloo\University\FYDP\CrowdQuote\ComputerVision-Subsystem\datasets\VisDrone\VisDrone2019-DET-val.zip...
# Downloading https://github.com/ultralytics/yolov5/releases/download/v1.0/VisDrone2019-DET-test-dev.zip to C:\Users\lekev\OneDrive - University of Waterloo\University\FYDP\CrowdQuote\ComputerVision-Subsystem\datasets\VisDrone\VisDrone2019-DET-test-dev.zip...
# Downloading https://github.com/ultralytics/yolov5/releases/download/v1.0/VisDrone2019-DET-test-challenge.zip to C:\Users\lekev\OneDrive - University of Waterloo\University\FYDP\CrowdQuote\ComputerVision-Subsystem\datasets\VisDrone\VisDrone2019-DET-test-challenge.zip...
# Unzipping C:\Users\lekev\OneDrive - University of Waterloo\University\FYDP\CrowdQuote\ComputerVision-Subsystem\datasets\VisDrone\VisDrone2019-DET-val.zip...
# Unzipping C:\Users\lekev\OneDrive - University of Waterloo\University\FYDP\CrowdQuote\ComputerVision-Subsystem\datasets\VisDrone\VisDrone2019-DET-test-challenge.zip...
# Unzipping C:\Users\lekev\OneDrive - University of Waterloo\University\FYDP\CrowdQuote\ComputerVision-Subsystem\datasets\VisDrone\VisDrone2019-DET-test-dev.zip...
# Unzipping C:\Users\lekev\OneDrive - University of Waterloo\University\FYDP\CrowdQuote\ComputerVision-Subsystem\datasets\VisDrone\VisDrone2019-DET-train.zip...
# Converting C:\Users\lekev\OneDrive - University of Waterloo\University\FYDP\CrowdQuote\ComputerVision-Subsystem\datasets\VisDrone\VisDrone2019-DET-train: 6471it [10:06, 10.68it/s]
# Converting C:\Users\lekev\OneDrive - University of Waterloo\University\FYDP\CrowdQuote\ComputerVision-Subsystem\datasets\VisDrone\VisDrone2019-DET-val: 548it [01:24,  6.46it/s]
# Converting C:\Users\lekev\OneDrive - University of Waterloo\University\FYDP\CrowdQuote\ComputerVision-Subsystem\datasets\VisDrone\VisDrone2019-DET-test-dev: 1610it [02:36, 10.27it/s]
# Dataset download success  (1187.4s), saved to C:\Users\lekev\OneDrive - University of Waterloo\University\FYDP\CrowdQuote\ComputerVision-Subsystem\datasets
#
# Downloading https://ultralytics.com/assets/Arial.ttf to C:\Users\lekev\AppData\Roaming\Ultralytics\Arial.ttf...
# 100%|██████████| 755k/755k [00:00<00:00, 9.59MB/s]
# WARNING:tensorflow:From c:\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# Overriding model.yaml nc=80 with nc=10
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.Conv                  [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.Conv                  [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.C2f                   [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.Conv                  [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.C2f                   [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.Conv                  [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.C2f                   [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.Conv                  [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.C2f                   [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.SPPF                  [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.Concat                [1]
#  12                  -1  1    591360  ultralytics.nn.modules.C2f                   [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.Concat                [1]
#  15                  -1  1    148224  ultralytics.nn.modules.C2f                   [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.Conv                  [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.Concat                [1]
#  18                  -1  1    493056  ultralytics.nn.modules.C2f                   [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.Conv                  [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.Concat                [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.C2f                   [768, 512, 1]
#  22        [15, 18, 21]  1   2119918  ultralytics.nn.modules.Detect                [10, [128, 256, 512]]
# Model summary: 225 layers, 11139470 parameters, 11139454 gradients, 28.7 GFLOPs
#
# Transferred 349/355 items from pretrained weights
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.001), 63 bias
# train: Scanning C:\Users\lekev\OneDrive - University of Waterloo\University\FYDP\CrowdQuote\ComputerVision-Subsystem\datasets\VisDrone\VisDrone2019-DET-train\labels...:   0%|          | 0/6471 [00:00<?, ?it/s]Scanning C:\Users\lekev\OneDrive - University of Waterloo\University\FYDP\CrowdQuote\ComputerVision-Subsystem\datasets\VisDrone\VisDrone2019-DET-train\labels... 8 images, 0 backgrounds, 0 corrupt:   0%|          | 8/6471 [00:00<01:20, 79.94it/s]Scanning C:\Users\lekev\OneDrive - University of Waterloo\University\FYDP\CrowdQuote\ComputerVision-Subsystem\datasets\VisDrone\VisDrone2019-DET-train\labels... 40 images, 0 backgrounds, 0 corrupt:   1%|          | 40/6471 [00:00<00:30, 208.34it/s]Scanning C:\Users\lekev\OneDrive - University of Waterloo\University\FYDP\CrowdQuote\ComputerVision-Subsystem\datasets\VisDrone\VisDrone2019-DET-train\labels... 61 images, 0 backgrounds, 0 corrupt:   1%|          | 61/6471 [00:00<00:33, 191.34it/s]Scanning C:\Users\lekev\OneDrive - University of Waterloo\University\FYDP\CrowdQuote\ComputerVision-Subsystem\datasets\VisDrone\VisDrone2019-DET-train\labels... 81 images, 0 backgrounds, 0 corrupt:   1%|▏         | 81/6471 [00:00<00:33, 192.27it/s]Scanning C:\Users\lekev\OneDrive - University of Waterloo\University\FYDP\CrowdQuote\ComputerVision-Subsystem\datasets\VisDrone\VisDrone2019-DET-train\labels... 101 images, 0 backgrounds, 0 corrupt:   2%|▏         | 101/6471 [00:00<00:36, 174.03it/s]Scanning C:\Users\lekev\OneDrive - University of Waterloo\University\FYDP\CrowdQuote\ComputerVision-Subsystem\datasets\VisDrone\VisDrone2019-DET-train\labels... 119 images, 0 backgrounds, 0 corrupt:   2%|▏         | 119/6471 [00:00<00:39, 161.33it/s]Scanning C:\Users\lekev\OneDrive - University of Waterloo\University\FYDP\CrowdQuote\ComputerVision-Subsystem\datasets\VisDrone\VisDrone2019-DET-train\labels... 136 images, 0 backgrounds, 0 corrupt:   2%|▏         | 136/6471 [00:00<00:40, 157.98it/s]Scanning C:\Users\lekev\OneDrive - University of Waterloo\University\FYDP\CrowdQuote\ComputerVision-Subsystem\datasets\VisDrone\VisDrone2019-DET-train\labels... 152 images, 0 backgrounds, 0 corrupt:   2%|▏         | 152/6471 [00:01<00:53, 117.92it/s]Scanning C:\Users\lekev\OneDrive - University of Waterloo\University\FYDP\CrowdQuote\ComputerVision-Subsystem\datasets\VisDrone\VisDrone2019-DET-train\labels... 171 images, 0 backgrounds, 0 corrupt:   3%|▎         | 171/6471 [00:01<00:47, 133.58it/s]Scanning C:\Users\lekev\OneDrive - University of Waterloo\University\FYDP\CrowdQuote\ComputerVision-Subsystem\datasets\VisDrone\VisDrone2019-DET-train\labels... 193 images, 0 backgrounds, 0 corrupt:   3%|▎         | 193/6471 [00:01<00:50, 123.93it/s]Scanning C:\Users\lekev\OneDrive - University of Waterloo\University\FYDP\CrowdQuote\ComputerVision-Subsystem\datasets\VisDrone\VisDrone2019-DET-train\labels... 207 images, 0 backgrounds, 0 corrupt:   3%|▎         | 207/6471 [00:01<00:51, 121.48it/s]Scanning C:\Users\lekev\OneDrive - University of Waterloo\University\FYDP\CrowdQuote\ComputerVision-Subsystem\datasets\VisDrone\VisDrone2019-DET-train\labels... 228 images, 0 backgrounds, 0 corrupt:   4%|▎         | 228/6471 [00:01<00:44, 138.88it/s]Scanning C:\Users\lekev\OneDrive - University of Waterloo\University\FYDP\CrowdQuote\ComputerVision-Subsystem\datasets\VisDrone\VisDrone2019-DET-train\labels... 243 images, 0 backgrounds, 0 corrupt:   4%|▍         | 243/6471 [00:01<00:51, 121.66it/s]Scanning C:\Users\lekev\OneDrive - University of Waterloo\University\FYDP\CrowdQuote\ComputerVision-Subsystem\datasets\VisDrone\VisDrone2019-DET-train\labels... 259 images, 0 backgrounds, 0 corrupt:   4%|▍         | 259/6471 [00:01<00:48, 127.69it/s]Scanning C:\Users\lekev\OneDrive - University of Waterloo\University\FYDP\CrowdQuote\ComputerVision-Subsystem\datasets\VisDrone\VisDrone2019-DET-train\labels... 282 images, 0 backgrounds, 0 corrupt:   4%|▍         | 282/6471 [00:01<00:43, 143.88it/s]Scanning C:\Users\lekev\OneDrive - University of Wat ...
# train: WARNING  C:\Users\lekev\OneDrive - University of Waterloo\University\FYDP\CrowdQuote\ComputerVision-Subsystem\datasets\VisDrone\VisDrone2019-DET-train\images\0000137_02220_d_0000163.jpg: 1 duplicate labels removed
# train: WARNING  C:\Users\lekev\OneDrive - University of Waterloo\University\FYDP\CrowdQuote\ComputerVision-Subsystem\datasets\VisDrone\VisDrone2019-DET-train\images\0000140_00118_d_0000002.jpg: 1 duplicate labels removed
# train: WARNING  C:\Users\lekev\OneDrive - University of Waterloo\University\FYDP\CrowdQuote\ComputerVision-Subsystem\datasets\VisDrone\VisDrone2019-DET-train\images\9999945_00000_d_0000114.jpg: 1 duplicate labels removed
# train: WARNING  C:\Users\lekev\OneDrive - University of Waterloo\University\FYDP\CrowdQuote\ComputerVision-Subsystem\datasets\VisDrone\VisDrone2019-DET-train\images\9999987_00000_d_0000049.jpg: 1 duplicate labels removed
# train: New cache created: C:\Users\lekev\OneDrive - University of Waterloo\University\FYDP\CrowdQuote\ComputerVision-Subsystem\datasets\VisDrone\VisDrone2019-DET-train\labels.cache
# val: Scanning C:\Users\lekev\OneDrive - University of Waterloo\University\FYDP\CrowdQuote\ComputerVision-Subsystem\datasets\VisDrone\VisDrone2019-DET-val\labels...:   0%|          | 0/548 [00:00<?, ?it/s]Scanning C:\Users\lekev\OneDrive - University of Waterloo\University\FYDP\CrowdQuote\ComputerVision-Subsystem\datasets\VisDrone\VisDrone2019-DET-val\labels... 18 images, 0 backgrounds, 0 corrupt:   3%|▎         | 18/548 [00:00<00:03, 162.30it/s]Scanning C:\Users\lekev\OneDrive - University of Waterloo\University\FYDP\CrowdQuote\ComputerVision-Subsystem\datasets\VisDrone\VisDrone2019-DET-val\labels... 35 images, 0 backgrounds, 0 corrupt:   6%|▋         | 35/548 [00:00<00:03, 151.78it/s]Scanning C:\Users\lekev\OneDrive - University of Waterloo\University\FYDP\CrowdQuote\ComputerVision-Subsystem\datasets\VisDrone\VisDrone2019-DET-val\labels... 58 images, 0 backgrounds, 0 corrupt:  11%|█         | 58/548 [00:00<00:02, 171.51it/s]Scanning C:\Users\lekev\OneDrive - University of Waterloo\University\FYDP\CrowdQuote\ComputerVision-Subsystem\datasets\VisDrone\VisDrone2019-DET-val\labels... 79 images, 0 backgrounds, 0 corrupt:  14%|█▍        | 79/548 [00:00<00:02, 184.54it/s]Scanning C:\Users\lekev\OneDrive - University of Waterloo\University\FYDP\CrowdQuote\ComputerVision-Subsystem\datasets\VisDrone\VisDrone2019-DET-val\labels... 100 images, 0 backgrounds, 0 corrupt:  18%|█▊        | 100/548 [00:00<00:02, 187.45it/s]Scanning C:\Users\lekev\OneDrive - University of Waterloo\University\FYDP\CrowdQuote\ComputerVision-Subsystem\datasets\VisDrone\VisDrone2019-DET-val\labels... 119 images, 0 backgrounds, 0 corrupt:  22%|██▏       | 119/548 [00:00<00:02, 188.01it/s]Scanning C:\Users\lekev\OneDrive - University of Waterloo\University\FYDP\CrowdQuote\ComputerVision-Subsystem\datasets\VisDrone\VisDrone2019-DET-val\labels... 138 images, 0 backgrounds, 0 corrupt:  25%|██▌       | 138/548 [00:00<00:02, 171.26it/s]Scanning C:\Users\lekev\OneDrive - University of Waterloo\University\FYDP\CrowdQuote\ComputerVision-Subsystem\datasets\VisDrone\VisDrone2019-DET-val\labels... 160 images, 0 backgrounds, 0 corrupt:  29%|██▉       | 160/548 [00:00<00:02, 176.44it/s]Scanning C:\Users\lekev\OneDrive - University of Waterloo\University\FYDP\CrowdQuote\ComputerVision-Subsystem\datasets\VisDrone\VisDrone2019-DET-val\labels... 178 images, 0 backgrounds, 0 corrupt:  32%|███▏      | 178/548 [00:01<00:02, 167.68it/s]Scanning C:\Users\lekev\OneDrive - University of Waterloo\University\FYDP\CrowdQuote\ComputerVision-Subsystem\datasets\VisDrone\VisDrone2019-DET-val\labels... 202 images, 0 backgrounds, 0 corrupt:  37%|███▋      | 202/548 [00:01<00:01, 178.84it/s]Scanning C:\Users\lekev\OneDrive - University of Waterloo\University\FYDP\CrowdQuote\ComputerVision-Subsystem\datasets\VisDrone\VisDrone2019-DET-val\labels... 220 images, 0 backgrounds, 0 corrupt:  40%|████      | 220/548 [00:01<00:01, 166.03it/s]Scanning C:\Users\lekev\OneDrive - University of Waterloo\University\FYDP\CrowdQuote\ComputerVision-Subsystem\datasets\VisDrone\VisDrone2019-DET-val\labels... 237 images, 0 backgrounds, 0 corrupt:  43%|████▎     | 237/548 [00:01<00:01, 161.90it/s]Scanning C:\Users\lekev\OneDrive - University of Waterloo\University\FYDP\CrowdQuote\ComputerVision-Subsystem\datasets\VisDrone\VisDrone2019-DET-val\labels... 254 images, 0 backgrounds, 0 corrupt:  46%|████▋     | 254/548 [00:01<00:01, 162.63it/s]Scanning C:\Users\lekev\OneDrive - University of Waterloo\University\FYDP\CrowdQuote\ComputerVision-Subsystem\datasets\VisDrone\VisDrone2019-DET-val\labels... 271 images, 0 backgrounds, 0 corrupt:  49%|████▉     | 271/548 [00:01<00:01, 153.07it/s]Scanning C:\Users\lekev\OneDrive - University of Waterloo\University\FYDP\CrowdQuote\ComputerVision-Subsystem\datasets\VisDrone\VisDrone2019-DET-val\labels... 287 images, 0 backgrounds, 0 corrupt:  52%|█████▏    | 287/548 [00:01<00:01, 154.58it/s]Scanning C:\Users\lekev\OneDrive - University of Waterloo\University\FYDP\CrowdQuote\ComputerVision ...
# val: New cache created: C:\Users\lekev\OneDrive - University of Waterloo\University\FYDP\CrowdQuote\ComputerVision-Subsystem\datasets\VisDrone\VisDrone2019-DET-val\labels.cache
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to runs\detect\train4
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100         0G      1.863      5.584      1.173       1237        640:   4%|▍         | 16/405 [19:04<5:54:43, 54.71s/it]
